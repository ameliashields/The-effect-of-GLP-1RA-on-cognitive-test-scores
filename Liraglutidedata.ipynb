# %% [markdown]
# <a href="https://colab.research.google.com/github/ameliashields/The-effect-of-GLP-1RA-on-cognitive-test-scores/blob/main/Liraglutidedata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
df = pd.read_excel("python vadini et al.xlsx")
print(df.head())
# Out:
#      <input type="file" id="files-c7e33238-a93f-4eb5-87dd-d6b730155b90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7e33238-a93f-4eb5-87dd-d6b730155b90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def p_to_stars(p):
  if p < 0.001: return "***"
  elif p < 0.01: return "**"
  elif p < 0.05: return "*"
df["stars"] = df["P-value"].apply(p_to_stars)

plt.figure(figsize=(10,6))
plt.bar(df["Test Name"], df["% change"], yerr=df["SD"], capsize=6, color="blue")
plt.axhline(0, color="black", linewidth=0.8)
plt.xticks(rotation=35, ha="right")
plt.ylabel("% Change in Cognitive Test Scores")
plt.title("% Change in Cognitive Test Scores following Liraglutide Treatment (Vadini et al., 2020\)")

for i, (val, err, star) in enumerate(zip(df["% change"], df["SD"], df["stars"])):
  plt.text(i, val + err + 1, star, ha="center", va="bottom")

plt.tight_layout()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_excel("Li et al data.xlsx")
print(df.head())
# Out:
#      <input type="file" id="files-f266ec32-6a8d-432c-8c77-e4f80ef12ffb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f266ec32-6a8d-432c-8c77-e4f80ef12ffb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def p_to_stars(p):
  if p < 0.001: return "***"
  elif p < 0.01: return "**"
  elif p < 0.05: return "*"
df["stars"] = df["p-value"].apply(p_to_stars)

plt.figure(figsize=(10,6))
plt.bar(df["Cognitive test"], df["% change"], yerr=df["SD"], capsize=6, color="blue")
plt.axhline(0, color="black", linewidth=0.8)
plt.xticks(rotation=35, ha="right")
plt.ylabel("% Change in Cognitive Test Scores")
plt.title("% Change in Cognitive Test Scores following Liraglutide Treatment, (Li et al., 2021)")

for i, (val, err, star) in enumerate(zip(df["% change"], df["SD"], df["stars"])):
  plt.text(i, val + err + 1, star, ha="center", va="bottom")

plt.tight_layout()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_excel("cheng et al.xlsx")
print(df.head())
# Out:
#      <input type="file" id="files-20d68b34-c048-426a-b637-1b6025317944" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20d68b34-c048-426a-b637-1b6025317944">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def p_to_stars(p):
  if p < 0.001: return "***"
  elif p < 0.01: return "**"
  elif p < 0.05: return "*"
df["stars"] = df["P-value"].apply(p_to_stars)

plt.figure(figsize=(10,6))
plt.bar(df["Cognitive test"], df["% change"], yerr=df["SD"], capsize=6, color="blue")
plt.axhline(0, color="black", linewidth=0.8)
plt.xticks(rotation=35, ha="right")
plt.ylabel("% Change in Cognitive Test Score")
plt.title("% Change in Cognitive Test Scores following Liraglutide Treatment (Cheng et al., 2022)")

for i, (val, err, star) in enumerate(zip(df["% change"], df["SD"], df["stars"])):
  plt.text(i, val + err + 1, star, ha="center", va="bottom")

plt.tight_layout()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_excel("gejl et al.xlsx")
print(df.head())
# Out:
#      <input type="file" id="files-9c719f9d-6a0a-40e7-ba7e-c2eb33942297" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c719f9d-6a0a-40e7-ba7e-c2eb33942297">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.figure(figsize=(10,6))
plt.bar(df["Cognitive test"], df["% change"], yerr=df["SD"], capsize=6, color="blue")
plt.axhline(0, color="black", linewidth=0.8)
plt.xticks(rotation=35, ha="right")
plt.ylabel("% Change in Cognitive Test Score")
plt.title("% Change in Cognitive Test Scores following Liraglutide Treatment (Gejl et al., 2016)")
# Out:
# Text(0.5, 1.0, '% Change in Cognitive Test Scores following Liraglutide Treatment (Gejl et al., 2016)')

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_excel("watson et al.xlsx")
print(df.head())
# Out:
#      <input type="file" id="files-9a4b60ab-eca1-46af-9f10-9f5142b288e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a4b60ab-eca1-46af-9f10-9f5142b288e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.figure(figsize=(10,6))
plt.bar(df["Cognitive test"], df["% change"], yerr=df["SD"], capsize=6, color="blue")
plt.axhline(0, color="black", linewidth=0.8)
plt.xticks(rotation=35, ha="right")
plt.ylabel("% Change in Cognitive Test Scores")
plt.title("% Change in Cognitive Test Scores following Liraglutide Treatment (Watson et al., 2019)")
plt.tight_layout()
plt.show()
